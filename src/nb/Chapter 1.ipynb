# %% [markdown]
# # Python for Engineering Analysis
#
# By
#
# **Olagoke Oladokun**
# **Bemgba Bevan Nyakuma**
# **Arshad Ahmad**
#
# ---

# %% [markdown]
# # Python Fundamental

# %% [markdown]
# ## Why Python?

# %% [markdown]
# Why ***python*** for Energy Engineering analysis?.
#
# 1. ***python*** is comparable to MATLAB and other scripting languages.
# 1. ***python*** is comparable to Fortran and other programming languages.
# 2. ***python*** contains all the scientific packages.
# 3. ***python*** can create beautiful Charts (matplotlib, plotly).
# 3. ***python*** can create Desktop App (Tk).
# 4. ***python*** can create Web App (Flask, Django).
# 5. ***python*** is for Data Science.
# 5. ***python*** can create Machine learning App (Dash).
# 6. ***python*** is **Free**.

# %% [markdown]
# I have worked with many scripting and programming languages.
# I can say ***python*** is one of the easiest and fun to work with, especially for engineering or scientific calculations.
# Infact ***python*** easily became my calculator.

# %% [markdown]
# ## ***Python*** Installation

# %% [markdown]
# Follow the steps below for ***python*** installation.
# (Note: The ***python*** foundation can change the installation process for any platform (Windows, Mac, Linux))

# %% [markdown]
# 1. Download the ***Python*** 3.8.3 (or latest) installer file, from **https://www.python.org/downloads/**
# 2. Launch or extract the installer file
# 2. Accept all the defaults.
# 4. Make sure the installation is added to your **PATH**
# 5. Verify installation by opening your cmd (command) window and type:
#
#     > *python -Version*
#
#     The response is below:
#
#     > Python 3.8.3

# %% [markdown]
# > ![2020-06-03 (2).png](attachment:c8fd46bf-ea31-462f-9624-40d79544a5a3.png)

# %% [markdown]
# Congratulations for making it this far. ***Python*** is installed and ready for use.

# %% [markdown]
# ## Package Installation

# %% [markdown]
# The focus of this book is to acquaint Engineers with tools nededed to solve and/or analyze engineering problems in ***Python***.
#
# It is important to clarify the focus because ***Python*** supports hundreds of packages and new packages are added everyday.

# %% [markdown]
# The basic packages but not limited for Engineering analysis are :

# %% [markdown]
# 1. numpy : for array, vector and matrix manipulation.
# 2. xlrd : for excel file import and export.
# 3. pandas : for data manipulation in table format.
# 4. scipy : for scientific manipulation
# 5. matplotlib : for creating charts

# %% [markdown]
# We will introduce each packages in the subsequent section in this chapter. Also in every chapter they are used, more indepth explanation will be done.

# %% [markdown]
# ## Coding Editor

# %% [markdown]
# For learning and editing python the recommended package is *Jupyter Notebook* or *Jupyter Lab*

# %% [markdown]
# ### Install Jupyter Lab

# %% [markdown]
# To install Jupyter Lab open your cmd windows and type:

# %% [markdown]
# > *pip install jupyterlab*

# %% [markdown]
# ![2020-06-03 (3).png](attachment:ca16300a-4fbe-4fe5-bde6-d6d465307a92.png)

# %% [markdown]
# ### Open jupyter lab

# %% [markdown]
# To open jupyter lab type in the cmd window:

# %% [markdown]
# > *jupyter lab*

# %% [markdown]
# ![2020-06-03 (5).png](attachment:e42ebb33-8d4b-457d-b2a6-c15f9883d868.png)

# %% [markdown]
# **Jupyter lab** will automatically open in your default browser.

# %% [markdown]
# ![2020-06-03 (7).png](attachment:5e6fd981-2a5d-419c-b01e-bafa6f0f6b52.png)

# %% [markdown]
# From the right pane in the browser select the ***Python 3.* *** under the **Notebook** section.
# An untitled.ipynb file will be created and open, see below.

# %% [markdown]
# ![2020-06-03 (9).png](attachment:d4d2b194-bf86-48c1-8b7e-10d8c938425c.png)

# %% [markdown]
# Congratulations! again you have a *jupyter Notebook* opened for your coding exercises.

# %% [markdown]
# If you need new Notebook file go to:
# > **File -> New -> Notebook**

# %% [markdown]
# ![2020-06-03 (11).png](attachment:bfa8b32e-fbd0-4032-81ff-2755d3201be0.png)

# %% [markdown]
# Please explore all the packages by going to their online documentation. This book is to get you started with python as fast as possible and solve some energy engineering problems encountered by the authors in course of research.

# %% [markdown]
# Happy Coding!

# %% [markdown]
# ## Python Basic

# %% [markdown]
# ### Data Types

# %% [markdown]
# Every programming or scripting languages works with data and there are basic fundamental data types to represent data and complex data structure.
#
# In ***Python*** the data type stores Numbers, Strings, Lists, Dictinaries, Sets to name a few.

# %% [markdown]
# #### Numbers

# %% [markdown]
# ***Python*** environment can serve as a calculator. Just use the normal arithmetic operation, such as +, -, * , / , ( ). Note they carry precedence as with arithmetic operations: ( ), *, /, +, -.

# %% [markdown]
# There are two basic number types in ***Python*** *integer* (23) and *float* (0.23).

# %% [markdown]
# Example: Number arithmetic operations

# %%
2 + 5
# Out:
# 7

# %%
2 + 5 * 2
# Out:
# 12

# %% [markdown]
# In Python to calculate power use **** operator**

# %%
# b^2 - (b - 4ac)^0.5

6**2 - (6 - 4*1*0.8)**0.5
# Out:
# 34.32667994693185

# %% [markdown]
# Data can be stored in name variable.

# %% [markdown]
# Example: create variable a, b and c that stores Number type: a(integer), b(integer) and c(float).

# %%
a = 1
b = 6
c = 0.8

x = b**2 - (b - 4*a*c)**0.5

print(x)
# Out:
# 34.32667994693185

# %%
# ax^2 + bx + c = 0
a = 1
b = 1
c = -2

x1 = (-b + (b**2 - 4*a*c)**0.5) / (2*a)
x2 = (-b - (b**2 - 4*a*c)**0.5) / (2*a)

print('root of x1: ', x1)
print('root of x2: ', x2)
# Out:
# root of x1:  1.0
# root of x2:  -2.0

# %% [markdown]
# #### Strings

# %% [markdown]
# A literal string must be in single or double quotes.

# %%
'Hello! Python Guys'
# Out:
# 'Hello! Python Guys'

# %% [markdown]
# Use double quote if the literal contains a single quote.

# %%
print("Hello! Python Guy's")
# Out:
# Hello! Python Guy's

# %% [markdown]
# Insert newline **\n**

# %%
print("Hello Guys, \nThis is the second line")
# Out:
# Hello Guys,
# This is the second line

# %% [markdown]
# Create multiline string using **"""..."""** and **'''...'''**.

# %%
letter = """
Hello Guys, 
This is the second line.
    - Guy1
    - Guy2
"""

print(letter)
# Out:
# Hello Guys,
# This is the second line.
#     - Guy1
#     - Guy2

# %% [markdown]
# To concatenate two Strings use + sign.

# %%
prefix = 'Engi'

print(prefix + 'neering')
# Out:
# Engineering

# %% [markdown]
# Strings characters can be access using indexed ([ *i* ]). The first character has index 0. Also the index of the last character is -1, The reverse access of string (sequence of characters) is negative index.

# %%
word = 'Engineering Mathematics'
print(word)

print('first character:', word[0])
print(word[2])
print('10th character: ', word[9])

print('23rd and [-1] and Last charater: ', word[22])

print('Last charater: ', word[-1])
print('2nd to last character: ', word[-2])
# Out:
# Engineering Mathematics
# first character: E
# g
# 10th character:  n
# 23rd and [-1] and Last charater:  s
# Last charater:  s
# 2nd to last character:  c

# %% [markdown]
# Apart from indexing, *slicing* is also supported. What is slicing, slicing get a range to data, by supplying the:
#
# > \[first-index : last-index-excluded]
#
# > \[ : last-index-excluded]  first-index = 0
#
# > \[first-index : ]  last-index-excluded = String-length

# %%
word = 'Engineering Mathematics'
print(word)

word[0:6]
# Out:
# Engineering Mathematics
# 'Engine'

# %%
word = 'Engineering Mathematics'
print(word)

word[4:20]
# Out:
# Engineering Mathematics
# 'neering Mathemat'

# %% [markdown]
# Get data from index 2 to the last character.

# %%
word = 'Engineering Mathematics'
print(word)

word[2:]
# Out:
# Engineering Mathematics
# 'gineering Mathematics'

# %% [markdown]
# Get data from index 0 or first character to the character at index 9.

# %%
word = 'Engineering Mathematics'
print(word)

word[:10]
# Out:
# Engineering Mathematics
# 'Engineerin'

# %% [markdown]
# **Warning**: accessing index beyond last record will result in error.

# %%
word[130]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-bcc5681df49b> in <module>
# ----> 1 word[130]
#
# IndexError: string index out of range

# %% [markdown]
# #### List

# %% [markdown]
# Most of the time you will need to store a list of data and/or values

# %%
cubes = [1, 9, 27, 64, 125]
cubes
# Out:
# [1, 9, 27, 64, 125]

# %% [markdown]
# Length or size of the list is determined by function *len*

# %%
len(cubes)
# Out:
# 5

# %% [markdown]
# Both ***Indexing*** and ***Slicing*** also works for list.

# %%
cubes[0]
# Out:
# 1

# %%
cubes[1:3]
# Out:
# [9, 27]

# %%
cubes = [1, 9, 27, 64, 125]

cubes[-1]
# Out:
# 125

# %%
cubes[2:]
# Out:
# [27, 64, 125]

# %%
cubes[:2]
# Out:
# [1, 9]

# %% [markdown]
# Changing the value of a list.

# %%
print(cubes[1])
cubes[1] = 2**3
cubes[1]
# Out:
# 9
# 8

# %% [markdown]
# Lists are mutable type, i.e when a new value is assigned to their contented they are permanently changed. Unlist String type that are immutable. Notice that the cube of 2 was changes from 9 to 8 the correct value..

# %%
cubes[:]
# Out:
# [1, 8, 27, 64, 125]

# %% [markdown]
# Lists can be added (concatenate) and its slice can be assign. Both operation can increase the size of the list.

# %%
title = ['C','H','e','E']
code = [3,0,6]

title + code
# Out:
# ['C', 'H', 'e', 'E', 3, 0, 6]

# %%
title[1:3]=['F','K','K']
title
# Out:
# ['C', 'F', 'K', 'K', 'E']

# %% [markdown]
# Clear the list by assigning all elements with an empty list.

# %%
title[:]=[]
title
# Out:
# []

# %% [markdown]
# Multidimensional Lists can be created from nested lists.

# %%
title = ['C','H','e','E']
code = [3,0,6]
mult_list = [title,code]
mult_list
# Out:
# [['C', 'H', 'e', 'E'], [3, 0, 6]]

# %%
mult_list = [title,code]
print(mult_list)

mult_list[0]
# Out:
# [['C', 'H', 'e', 'E'], [3, 0, 6]]
# ['C', 'H', 'e', 'E']

# %%
mult_list[1]
# Out:
# [3, 0, 6]

# %%
mult_list[0][1]
# Out:
# 'H'

# %% [markdown]
# Lets create list of squared numbers from 0-10.

# %%
num_list = [1,2,3,4,5,6,7,8,9]
squares = []

for n in num_list:
    print(n)
    squares.append(n**2)
    
squares
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# The above is a small program on getting the list of squares. More explanation as we proceed in the book.
# > 1. *num_list = [1,2,3,4,5,6,7,8,9]* : creates a list of numbers from 1 - 9
# > 1. *squares = []* : creates an empty list
# > 2. *for n in num_list:* : for iterate over the values in num_list and put them in n.
# > 3. *print(n)* : print n to screen.
# > 4. *squares.append(n\*\*2)* : compute the square of n and append to the end of the squares list.

# %% [markdown]
# There are other functions for List such as extend, insert, pop, reverse, remove etc. Please check them out.

# %%
squares.pop()
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
squares.insert(0,81)
squares
# Out:
# [81, 1, 4, 9, 16, 25, 36, 49, 64]

# %%
squares.reverse()
squares
# Out:
# [64, 49, 36, 25, 16, 9, 4, 1, 81]

# %% [markdown]
# #### Tuples and Sequences

# %% [markdown]
# ***string***, ***list*** allow indexing and slicing, they are Sequence data types and so is ***tuple and range***

# %% [markdown]
# A tuple consists of values separated by commas:

# %%
t = 1357, 2468, 'python!'
t
# Out:
# (1357, 2468, 'python!')

# %%
t[1]
# Out:
# 2468

# %% [markdown]
# Nested tuple can be created. However tuples are immutable like string.

# %%
tt = t,(1,2,3,4)
tt
# Out:
# ((1357, 2468, 'python!'), (1, 2, 3, 4))

# %%
tt[0]
# Out:
# (1357, 2468, 'python!')

# %%
tt[0]=28,'kate'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-0a4052df262f> in <module>
# ----> 1 tt[0]=28,'kate'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ##### Packing and Unpacking

# %%
# packing
t = 1357, 2468, 'python!'

t
# Out:
# (1357, 2468, 'python!')

# %%
# unpacking
x,y,z = t

print('x: ', x)
print('y: ', y)
print('z: ', z)
# Out:
# x:  1357
# y:  2468
# z:  python!

# %% [markdown]
# #### range() Function

# %% [markdown]
# The *range()* function returns a sequence of integer. It takes one to three (1-3) arguments. *range(start, end, step)* all are optional except end.

# %%
range(10)
# Out:
# range(0, 10)

# %% [markdown]
# The best way is to iterate over the sequence or convert to a list.

# %%
# get value from 0 to 5

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# get value from 3 to 8
list(range(3,9))
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
# get value from 0 to 9 at step of 3

list(range(0,10,3))
# Out:
# [0, 3, 6, 9]

# %% [markdown]
# #### Dictionaries

# %% [markdown]
# Dictionary (Dict) are key-value type. The indexing is the key and not number.

# %%
my_dict = {'a': 65, 'b': 66, 'c': 67, 'd':68}
my_dict
# Out:
# {'a': 65, 'b': 66, 'c': 67, 'd': 68}

# %%
my_dict['b']
# Out:
# 66

# %%
for (k,v) in my_dict.items():
    print(k,v)
# Out:
# a 65
# b 66
# c 67
# d 68

# %% [markdown]
# #### Sets

# %% [markdown]
# Set is an unoredered collection and does not allow duplicate value.

# %%
my_set = {'mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun', 'mon'}
my_set
# Out:
# {'fri', 'mon', 'sat', 'sun', 'thu', 'tue', 'wed'}

# %%
'wed' in my_set
# Out:
# True

# %% [markdown]
# #### Boolean

# %% [markdown]
# Boolean data type contains two values *True* or *False*.

# %%
2 < 0
# Out:
# False

# %%
2 > 0
# Out:
# True

# %%
b_cond = 5 > 10

b_cond
# Out:
# False

# %%
is_done = True
is_done
# Out:
# True

# %%
is_not_done = False
is_not_done
# Out:
# False

# %% [markdown]
# ### Control Flow Statements

# %% [markdown]
# #### *if* Statements

# %% [markdown]
# The if statement type is a conditional or decision statement. It operates on the principle that a thing is done base on the truthee state of a question.

# %%
yob = int(input("Please enter your year of birth: "))
current_year = 2020

if yob < 0:
    print('Your year of birth is negative ???')
elif yob == 0:
    print('Your year of birth is zero ??')
elif yob < 1900:
    print('Your year of birth is less than 1900 ?')
elif yob > current_year:
    print('Your year of birth greater than 2020 ?')    
else:
    age = current_year - yob
    
    msg1 = 'You are {age} years old in {cy}'.format(age=age, cy=current_year)
    msg2 = 'You are {0} years old in {1}'.format(age, current_year)
    msg3 = 'You are {} years old in {}'.format(age, current_year)
    
    print(msg1) 
    print(msg2) 
    print(msg3)
# Out:
# Please enter your year of birth: 1985
# You are 35 years old in 2020
# You are 35 years old in 2020
# You are 35 years old in 2020

# %% [markdown]
# The code above receive input from keyboard using :
# > *input("Please enter your year of birth: ")*
#
# and convert or cast the value to integer using the expression.
# > *int( )*

# %% [markdown]
# #### *for* Statements

# %% [markdown]
# We have used the ***for** statement in earlier sections. The ***for*** statement iterate over a *list* items.

# %%
props = ['name','formulae','molar mass']
for p in props:
    print(p, len(p))
# Out:
# name 4
# formulae 8
# molar mass 10

# %% [markdown]
# To get the sum of odd numbers from 1-10.

# %%
start = 1
step = 2
N = 10

sum = 0
for n in range(start,N,step):
    sum = sum + n
    print('odd={0}: sum = {1}'.format(n,sum))
# Out:
# odd=1: sum = 1
# odd=3: sum = 4
# odd=5: sum = 9
# odd=7: sum = 16
# odd=9: sum = 25

# %% [markdown]
# **Quiz**
# Try the sum of even numbers.

# %% [markdown]
# #### *while* Statements

# %% [markdown]
# **while** statements also iterates over a list. However, it only checks if a condition is *True* or *False* to continue to iterate.

# %%
n = 0
step = 1
end = 5

while n < end:
    print(n)
    n += step
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n = 0
step = 2
end = 10

sum = 0
while n < end:
    sum += n
    print('even: {n} -> sum: {sum}'.format(n=n,sum=sum))
    n += step
# Out:
# even: 0 -> sum: 0
# even: 2 -> sum: 2
# even: 4 -> sum: 6
# even: 6 -> sum: 12
# even: 8 -> sum: 20

# %% [markdown]
# #### *break and continue Statements, and else Clauses* on Loops

# %% [markdown]
# The ***break*** statement breaks out of a loop, the innermost enclosing loop in a ***for*** or ***while***.
#
# Unlike any main programming language the ***Python*** has a cool feature in loop statements having an ***else*** clause. It is executed after ***for*** loop termination and ***while*** loop condition is false.

# %% [markdown]
# Example: Find the prime numbers from zero to a number.

# %%
start = 2
end = 10

primes = []

for n in range(start, end):
    for x in primes:
        if n % x == 0:
            print(n, 'is a multiple of', x)
            break
    else:
        # loop fell through without finding a factor
        print(n, 'is a prime number')
        primes.append(n)
primes
# Out:
# 2 is a prime number
# 3 is a prime number
# 4 is a multiple of 2
# 5 is a prime number
# 6 is a multiple of 2
# 7 is a prime number
# 8 is a multiple of 2
# 9 is a multiple of 3
# [2, 3, 5, 7]

# %% [markdown]
# #### *pass* Statements

# %% [markdown]
# The ***pass*** statement is a placeholder and does nothing. It is commonly used for creating minimal ***functions*** and ***classes***.

# %%
class MyEmptyClass:
    pass

# %%
def my_empty_func(*args):
    pass

# %% [markdown]
# ### *Functions*

# %% [markdown]
# Functions are used to contain an expression or formula that will be called several times. The keyword for creating function is ***def***.
#
# > def function_name ( \[ [ [ arg1, ] arg2, ] ... ] ):

# %% [markdown]
# Example: Create a function that greets

# %%
def greetings():
    print('Hello! Player 1')

# %% [markdown]
# Call the function by using the function name follow by the parenthesis.

# %%
greetings()
# Out:
# Hello! Player 1

# %% [markdown]
# Example: Create a function to get a list of primes

# %%
def primes(N):
    """Get a list of Primes from zero to N."""
    primes = []

    for n in range(2, N):
        for x in primes:
            if n % x == 0:
                break
        else:
            # loop fell through without finding a factor
            primes.append(n)
    return primes

# %% [markdown]
# Call the primes function and pass the argument it is expecting in this case and integer.

# %%
primes(20)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]

# %% [markdown]
# #### Default Argument Values

# %% [markdown]
# It possible to define a **function** with default value for one or more of the arguments. e.g *arg=value*

# %% [markdown]
# Example: Create *primes* function that return prime numbers within specify range. It takes two(2) arguments with the from_num having default value of 2.

# %%
def primes2(to_num, from_num=2):
    """Get a list of Primes from from_num to to_num."""
    primes = []
    final_primes = []

    for n in range(2, to_num):
        for x in primes:
            if n % x == 0:
                break
        else:
            # loop fell through without finding a factor
            primes.append(n)
            if n >= from_num:
                final_primes.append(n)
            
    # get the index of from_num
    return final_primes

# %% [markdown]
# Call the primes2 with the 2 positional arguments supplied.

# %%
primes2(213, 175)
# Out:
# [179, 181, 191, 193, 197, 199, 211]

# %% [markdown]
# Call the primes2 with 1 positional and 2 positional arguments supplied.

# %%
# call primes
p1 = primes(20)

# call primes2
p2 = primes2(20)
p2_20_5 = primes2(20,5)
p2_20_8 = primes2(20,8)
p2_20_21 = primes2(20,21)

print(p1)
print(p2) 
print(p2_20_5) 
print(p2_20_8) 
print(p2_20_21)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]
# [2, 3, 5, 7, 11, 13, 17, 19]
# [5, 7, 11, 13, 17, 19]
# [11, 13, 17, 19]
# []

# %% [markdown]
# Take note that *None* was the return value for the last caller:
# > *p2_20_21 = primes2(20,21)*

# %% [markdown]
# ***None*** value represent nothing data type.

# %% [markdown]
# #### Keyword Argument Values

# %% [markdown]
# Functions can also be called by ***keywords*** arguments of the form *kwarg=value*.

# %%
def primes3(to_num, from_num=2, count=3):
    """Get a list of Primes from from_num to to_num."""
    primes = []

    for n in range(2, to_num):
        for x in primes:
            if n % x == 0:
                break
        else:
            # loop fell through without finding a factor
            primes.append(n)
    
    # check if from_num is in primes list    
    if from_num in primes:
        # get index
        i = primes.index(from_num)
        return primes[i:(i+count)]
    else:
        # get index above from_num
        for i in range(len(primes)):
            if from_num < primes[i]:
                return primes[i:(i+count)]

# %% [markdown]
# Call the primes3 with 1 positional and 2 keyword arguments supplied.

# %%
# call primes
p1 = primes(20)

# call primes2
p2 = primes2(20)

# call primes3
p3 = primes3(20, from_num=0)
p3_20_5 = primes3(20,from_num=5)

# note the swap in count and from_num.
p3_200_8_5 = primes3(200,from_num=8,count=5)
p3_200_111_6 = primes3(200, count=6,from_num=111)

print(p1)
print(p2) 
print('===')
print('p3:', p3)

print('p3_20_5:',p3_20_5) 
print('p3_200_8_5:',p3_200_8_5) 
print('p3_200_111_6:',p3_200_111_6)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]
# [2, 3, 5, 7, 11, 13, 17, 19]
# ===
# p3: [2, 3, 5]
# p3_20_5: [5, 7, 11]
# p3_200_8_5: [11, 13, 17, 19, 23]
# p3_200_111_6: [113, 127, 131, 137, 139, 149]
